# %% [markdown]
# https://www.kaggle.com/datasets/uciml/red-wine-quality-cortez-et-al-2009

# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt  
import pandas as pd
import seaborn as sns


from warnings import filterwarnings
filterwarnings(action='ignore')

# %% [markdown]
# # Loading Dataset

# %%
wine = pd.read_csv("/Users/yunperez/Documents/GitHub/EC_Project/data/winequality_mod.csv")
wine.sample(25)
# Out:
#       Unnamed: 0   density   alcohol  citric.acid  residual.sugar        pH  \
# 14            15  3.271255  3.217391     4.361446        3.574387  2.813953
# 4560        4561  1.308849  8.565217     2.192771        1.552147  5.255814
# 4985        4986  2.646617  3.086957     2.409639        1.179448  5.674419
# 2369        2370  2.323887  4.521739     2.572289        1.745399  7.697674
# 2421        2422  2.698670  2.956522     3.331325        2.539110  4.767442
# 5405        5406  3.236553  2.956522     3.981928        1.234663  4.139535
# 3844        3845  1.657606  5.826087     2.355422        1.262270  3.930233
# 1901        1902  2.230191  4.130435     2.626506        2.007669  2.674419
# 3329        3330  1.659341  4.913043     2.843373        1.110429  3.093023
# 1011        1012  2.056680  5.173913     3.222892        1.151840  4.627907
# 6137        6138  2.348178  5.956522     1.000000        1.510736  6.093023
# 1012        1013  2.247542  4.000000     3.602410        1.151840  4.000000
# 4432        4433  1.579526  7.130435     2.409639        1.662577  4.000000
# 1032        1033  2.750723  3.869565     2.951807        1.855828  6.372093
# 6102        6103  2.427993  4.913043     3.493976        1.207055  5.744186
# 506          507  2.264893  2.043478     2.409639        1.372699  3.023256
# 4868        4869  2.063621  4.652174     2.680723        1.538344  5.116279
# 2657        2658  1.702718  5.043478     3.277108        1.082822  4.837209
# 3834        3835  2.299595  2.565217     2.192771        1.579755  3.930233
# 6038        6039  2.698670  2.956522     2.626506        1.151840  5.813953
# 5993        5994  2.840949  4.260870     3.548193        1.262270  4.000000
# 3075        3076  1.452863  6.478261     3.168675        1.124233  3.720930
# 577          578  1.484095  7.130435     2.789157        1.303681  4.000000
# 19            20  2.455755  2.956522     1.759036        1.952454  4.488372
# 1915        1916  1.744361  6.869565     2.951807        1.703988  2.465116
#
#       type  quality
# 14       0        2
# 4560     0        3
# 4985     1        2
# 2369     0        3
# 2421     0        2
# 5405     1        3
# 3844     0        3
# 1901     0        2
# 3329     0        3
# 1011     0        4
# 6137     1        1
# 1012     0        3
# 4432     0        3
# 1032     0        3
# 6102     1        4
# 506      0        2
# 4868     0        3
# 2657     0        4
# 3834     0        2
# 6038     1        3
# 5993     1        2
# 3075     0        4
# 577      0        4
# 19       0        2
# 1915     0        4

# %%
wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      6497 non-null   int64
#  1   density         6497 non-null   float64
#  2   alcohol         6497 non-null   float64
#  3   citric.acid     6497 non-null   float64
#  4   residual.sugar  6497 non-null   float64
#  5   pH              6497 non-null   float64
#  6   type            6497 non-null   int64
#  7   quality         6497 non-null   int64
# dtypes: float64(5), int64(3)
# memory usage: 406.2 KB

# %% [markdown]
# # Description

# %%
wine.describe()
# Out:
#         Unnamed: 0      density      alcohol  citric.acid  residual.sugar  \
# count  6497.000000  6497.000000  6497.000000  6497.000000     6497.000000
# mean   3249.000000     2.316362     4.250175     2.727529        1.668545
# std    1875.666681     0.520302     1.555711     0.787868        0.656752
# min       1.000000     1.000000     1.000000     1.000000        1.000000
# 25%    1625.000000     1.907461     2.956522     2.355422        1.165644
# 50%    3249.000000     2.349913     4.000000     2.680723        1.331288
# 75%    4873.000000     2.714286     5.304348     3.114458        2.035276
# max    6497.000000    10.000000    10.000000    10.000000       10.000000
#
#                 pH      quality
# count  6497.000000  6497.000000
# mean      4.477913     2.818378
# std       1.121771     0.873255
# min       1.000000     0.000000
# 25%       3.720930     2.000000
# 50%       4.418605     3.000000
# 75%       5.186047     3.000000
# max      10.000000     6.000000

# %% [markdown]
# # Finding Null Values

# %%
wine.isnull().sum()
# Out:
# Unnamed: 0        0
# density           0
# alcohol           0
# citric.acid       0
# residual.sugar    0
# pH                0
# type              0
# quality           0
# dtype: int64

# %%
wine.groupby('quality').mean()
# Out:
#           Unnamed: 0   density   alcohol  citric.acid  residual.sugar  \
# quality
# 0        3240.566667  2.498091  3.889130     2.523494        1.626687
# 1        3036.652778  2.339960  3.843599     2.476406        1.490542
# 2        3390.923761  2.516308  3.397108     2.668373        1.718360
# 3        3276.365303  2.292367  4.375069     2.754363        1.683248
# 4        3060.094532  2.043825  5.416529     2.814984        1.570326
# 5        2628.512953  1.937569  5.798378     2.802922        1.660216
# 6         981.400000  1.754772  6.452174     3.092771        1.485890
#
#                pH      type
# quality
# 0        4.751163  0.333333
# 1        4.569444  0.245370
# 2        4.433876  0.318522
# 3        4.472505  0.224965
# 4        4.544690  0.184430
# 5        4.510784  0.093264
# 6        5.102326  0.000000

# %% [markdown]
# # Data Analysis

# %% [markdown]
# ## Countplot:

# %%
sns.countplot(wine['quality'])
plt.show()

# %%
wine.plot(kind ='box',subplots = True, layout =(4,4),sharex = False)
# Out:
# Unnamed: 0           Axes(0.125,0.712609;0.168478x0.167391)
# density           Axes(0.327174,0.712609;0.168478x0.167391)
# alcohol           Axes(0.529348,0.712609;0.168478x0.167391)
# citric.acid       Axes(0.731522,0.712609;0.168478x0.167391)
# residual.sugar       Axes(0.125,0.511739;0.168478x0.167391)
# pH                Axes(0.327174,0.511739;0.168478x0.167391)
# type              Axes(0.529348,0.511739;0.168478x0.167391)
# quality           Axes(0.731522,0.511739;0.168478x0.167391)
# dtype: object

# %% [markdown]
# ## Histogram

# %%
wine.hist(figsize=(10,10),bins=50)
plt.show()

# %% [markdown]
# # Feature Selection

# %%
wine.sample(5)
# Out:
#       Unnamed: 0   density   alcohol  citric.acid  residual.sugar        pH  \
# 5216        5217  3.045691  5.565217     3.114458        1.358896  5.534884
# 4731        4732  2.058415  5.826087     3.060241        2.366564  5.325581
# 1651        1652  2.854829  2.304348     5.012048        2.684049  3.790698
# 1273        1274  2.160787  4.782609     3.548193        1.069018  4.418605
# 4610        4611  1.850202  4.652174     2.951807        1.262270  4.488372
#
#       type  quality
# 5216     1        4
# 4731     0        3
# 1651     0        3
# 1273     0        2
# 4610     0        3

# %%
wine['quality'].unique()
# Out:
# array([3, 2, 4, 5, 1, 0, 6])

# %%
# If wine quality is 7 or above then will consider as good quality wine
wine['goodquality'] = [1 if x >= 5 else 0 for x in wine['quality']]
wine.sample(5)
# Out:
#       Unnamed: 0   density   alcohol  citric.acid  residual.sugar        pH  \
# 915          916  1.917872  2.565217     1.271084        1.027607  5.465116
# 4569        4570  2.126084  2.826087     2.734940        1.303681  4.209302
# 4755        4756  1.501446  6.739130     4.957831        1.220859  3.790698
# 847          848  1.865818  4.652174     2.463855        1.082822  3.511628
# 4405        4406  2.389821  2.826087     1.867470        2.007669  4.418605
#
#       type  quality  goodquality
# 915      0        2            0
# 4569     0        3            0
# 4755     0        3            0
# 847      0        2            0
# 4405     0        2            0

# %%
# See total number of good vs bad wines samples
wine['goodquality'].value_counts()
# Out:
# 0    6299
# 1     198
# Name: goodquality, dtype: int64

# %%
# Separate depedent and indepedent variables
X = wine.drop(['quality','goodquality'], axis = 1)
Y = wine['goodquality']

# %%
X
# Out:
#       Unnamed: 0   density   alcohol  citric.acid  residual.sugar        pH  \
# 0              1  3.410064  2.043478     2.951807        3.774540  2.953488
# 1              2  2.195489  2.956522     2.843373        1.138037  5.046512
# 2              3  2.386350  3.739130     3.168675        1.869632  4.767442
# 3              4  2.473106  3.478261     2.734940        2.090491  4.279070
# 4              5  2.473106  3.478261     2.734940        2.090491  4.279070
# ...          ...       ...       ...          ...             ...       ...
# 6492        6493  2.351648  4.260870     1.433735        1.193252  6.093023
# 6493        6494  2.389821  5.173913     1.542169        1.220859  6.581395
# 6494        6495  2.497397  4.913043     1.704819        1.234663  5.883721
# 6495        6496  2.450549  3.869565     1.650602        1.193252  6.930233
# 6496        6497  2.454020  4.913043     3.548193        1.414110  5.674419
#
#       type
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# ...    ...
# 6492     1
# 6493     1
# 6494     1
# 6495     1
# 6496     1
#
# [6497 rows x 7 columns]

# %%
print(Y)
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 6492    0
# 6493    0
# 6494    0
# 6495    0
# 6496    0
# Name: goodquality, Length: 6497, dtype: int64

# %% [markdown]
# # Feature Importance

# %%
from sklearn.ensemble import ExtraTreesClassifier
classifiern = ExtraTreesClassifier()
classifiern.fit(X,Y)
score = classifiern.feature_importances_
print(score)
# Out:
# [0.17680912 0.16207875 0.1843271  0.14654855 0.16535184 0.16161989
#  0.00326474]

# %% [markdown]
# # Splitting Dataset

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.3,random_state=7)

# %% [markdown]
# # Result

# %%
model_res=pd.DataFrame(columns=['Model', 'Score'])

# %% [markdown]
# # LogisticRegression:

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train,Y_train)
y_pred = model.predict(X_test)

from sklearn.metrics import accuracy_score,confusion_matrix
# accuracy_score(Y_test,Y_pred)
model_res.loc[len(model_res)] = ['LogisticRegression', accuracy_score(Y_test,y_pred)]
model_res
# Out:
#                 Model     Score
# 0  LogisticRegression  0.965128

# %% [markdown]
# # Using KNN:

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors=3)
model.fit(X_train,Y_train)
y_pred = model.predict(X_test)

from sklearn.metrics import accuracy_score
model_res.loc[len(model_res)] = ['KNeighborsClassifier', accuracy_score(Y_test,y_pred)]
model_res
# Out:
#                   Model     Score
# 0    LogisticRegression  0.965128
# 1  KNeighborsClassifier  0.962564

# %% [markdown]
# ##### Using SVC:

# %%
from sklearn.svm import SVC
model = SVC()
model.fit(X_train,Y_train)
y_pred = model.predict(X_test)

from sklearn.metrics import accuracy_score
print("Accuracy Score:",accuracy_score(Y_test,y_pred))
model_res.loc[len(model_res)] = ['SVC', accuracy_score(Y_test,y_pred)]
model_res
# Out:
# Accuracy Score: 0.9651282051282051
#                   Model     Score
# 0    LogisticRegression  0.965128
# 1  KNeighborsClassifier  0.962564
# 2                   SVC  0.965128

# %% [markdown]
# # Using Decision Tree:

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(criterion='entropy',random_state=7)
model.fit(X_train,Y_train)
y_pred = model.predict(X_test)

from sklearn.metrics import accuracy_score
print("Accuracy Score:",accuracy_score(Y_test,y_pred))
model_res.loc[len(model_res)] = ['DecisionTreeClassifier', accuracy_score(Y_test,y_pred)]
model_res
# Out:
# Accuracy Score: 0.9594871794871795
#                     Model     Score
# 0      LogisticRegression  0.965128
# 1    KNeighborsClassifier  0.962564
# 2                     SVC  0.965128
# 3  DecisionTreeClassifier  0.959487

# %% [markdown]
# # Using GaussianNB:

# %%
from sklearn.naive_bayes import GaussianNB
model3 = GaussianNB()
model3.fit(X_train,Y_train)
y_pred = model3.predict(X_test)

from sklearn.metrics import accuracy_score
print("Accuracy Score:",accuracy_score(Y_test,y_pred))
model_res.loc[len(model_res)] = ['GaussianNB', accuracy_score(Y_test,y_pred)]
model_res
# Out:
# Accuracy Score: 0.9507692307692308
#                     Model     Score
# 0      LogisticRegression  0.965128
# 1    KNeighborsClassifier  0.962564
# 2                     SVC  0.965128
# 3  DecisionTreeClassifier  0.959487
# 4              GaussianNB  0.950769

# %% [markdown]
# # Using Random Forest:

# %%
from sklearn.ensemble import RandomForestClassifier
model2 = RandomForestClassifier(random_state=1)
model2.fit(X_train, Y_train)
y_pred = model2.predict(X_test)

from sklearn.metrics import accuracy_score
print("Accuracy Score:",accuracy_score(Y_test,y_pred))
model_res.loc[len(model_res)] = ['RandomForestClassifier', accuracy_score(Y_test,y_pred)]
model_res
# Out:
# Accuracy Score: 0.9738461538461538
#                     Model     Score
# 0      LogisticRegression  0.965128
# 1    KNeighborsClassifier  0.962564
# 2                     SVC  0.965128
# 3  DecisionTreeClassifier  0.959487
# 4              GaussianNB  0.950769
# 5  RandomForestClassifier  0.973846

# %%
# !pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-2.0.2-py3-none-macosx_12_0_arm64.whl.metadata (2.0 kB)
# Requirement already satisfied: numpy in /Users/yunperez/anaconda3/lib/python3.11/site-packages (from xgboost) (1.24.3)
# Requirement already satisfied: scipy in /Users/yunperez/anaconda3/lib/python3.11/site-packages (from xgboost) (1.10.1)
# Downloading xgboost-2.0.2-py3-none-macosx_12_0_arm64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 8.3 MB/s eta 0:00:00m eta 0:00:010:00:01
# Installing collected packages: xgboost
# Successfully installed xgboost-2.0.2

# %% [markdown]
# # Using Xgboost:

# %%
import xgboost as xgb
model5 = xgb.XGBClassifier(random_state=1)
model5.fit(X_train, Y_train)
y_pred = model5.predict(X_test)

from sklearn.metrics import accuracy_score
print("Accuracy Score:",accuracy_score(Y_test,y_pred))
model_res.loc[len(model_res)] = ['XGBClassifier', accuracy_score(Y_test,y_pred)]
model_res
# Out:
# Accuracy Score: 0.9728205128205129
#                     Model     Score
# 0      LogisticRegression  0.965128
# 1    KNeighborsClassifier  0.962564
# 2                     SVC  0.965128
# 3  DecisionTreeClassifier  0.959487
# 4              GaussianNB  0.950769
# 5  RandomForestClassifier  0.973846
# 6           XGBClassifier  0.972821

# %%
model_res = model_res.sort_values(by='Score', ascending=False)
model_res
# Out:
#                     Model     Score
# 5  RandomForestClassifier  0.973846
# 6           XGBClassifier  0.972821
# 0      LogisticRegression  0.965128
# 2                     SVC  0.965128
# 1    KNeighborsClassifier  0.962564
# 3  DecisionTreeClassifier  0.959487
# 4              GaussianNB  0.950769
